# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17516 (delta 7), reused 0 (delta 0), pack-reused 17496 (from 4)
# Receiving objects: 100% (17516/17516), 16.62 MiB | 28.51 MiB/s, done.
# Resolving deltas: 100% (12002/12002), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...

# %%
import zipfile
import os

# Ensure the destination directory exists
os.makedirs("/content/dataset", exist_ok=True)

# TODO: Add code here to upload or download the 'data.zip' file
# Example (if uploading manually): Make sure 'data.zip' is uploaded to the current directory (/content/yolov5)
# Example (if downloading from a URL):
# !wget <URL_to_data.zip>


# Extract the data.zip file
with zipfile.ZipFile("/content/data.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/dataset")

print("✅ Extracted data.zip to /content/dataset")
# Out:
# ✅ Extracted data.zip to /content/dataset

# %%
data_yaml = """
train: /content/dataset/train/images
val: /content/dataset/val/images

nc: 1
names: ['your_class_name']  # 👈 Đổi tên class ở đây nếu có nhiều
"""
with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset/data.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --name yolov5-custom
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#       43/49      4.71G    0.02156   0.005747   0.006475         34        640:  54% 207/381 [01:11<00:54,  3.22it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       43/49      4.71G    0.02158   0.005757   0.006476         27        640:  55% 208/381 [01:12<00:50,  3.42it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       43/49      4.71G    0.02157   0.005754   0.006495         30        640:  55% 209/381 [01:12<00:55,  3.10it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
import shutil

# 📁 Đường dẫn tới thư mục bạn muốn zip
folder_to_zip = "/content/yolov5/runs/train/yolov5-custom3"

# 📄 Tên file zip đầu ra (nằm ở /content/)
output_zip = "/content/yolov5-custom.zip"

# 🔃 Đóng gói thư mục
shutil.make_archive(base_name=output_zip.replace(".zip", ""), format='zip', root_dir=folder_to_zip)

print(f"✅ Đã tạo file zip: {output_zip}")
# Out:
# ✅ Đã tạo file zip: /content/yolov5-custom.zip

# %%
# !python detect.py \
  --weights runs/train/yolov5-custom3/weights/best.pt \
  --img 640 \
  --conf 0.25 \
  --source /content/bien-bao-giao-thong-14.jpg
# Out:
# detect: weights=['runs/train/yolov5-custom3/weights/best.pt'], source=/content/bien-bao-giao-thong-14.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7112611 parameters, 0 gradients, 16.1 GFLOPs
# image 1/1 /content/bien-bao-giao-thong-14.jpg: 480x640 1 Motobike ban, 1 No parking, 1 No parking stopping, 1 One way, 46.8ms
# Speed: 0.6ms pre-process, 46.8ms inference, 196.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
